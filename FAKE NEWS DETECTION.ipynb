# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\angur\\Downloads'

# %%
os.chdir(r'C:\Users\angur\Downloads')

# %%
data_fake = pd.read_csv('Fake.csv')

# %%
data_true = pd.read_csv('True.csv')

# %%
data_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
data_true.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
data_fake["class"] = 0
data_true["class"] = 1

# %%
data_fake.shape , data_true.shape#shape return the shpae of array . shape is a tuple of integer #
# Out:
# ((23481, 5), (21417, 5))

# %%
data_fake_manual_testing = data_fake.tail(10)

for i in range(23480, 23470, -1):
    if i in data_fake.index:
        data_fake.drop([i], axis=0, inplace=True)

data_true_manual_testing = data_true.tail(10)

for i in range(21416, 21306, -1):
    if i in data_true.index:
        data_true.drop([i], axis=0, inplace=True)

# %%
data_fake.shape,data_true.shape
# Out:
# ((23461, 5), (21307, 5))

# %%
data_fake_manual_testing['class'] = 0
data_true_manual_testing ['class'] = 1
# Out:
# C:\Users\angur\AppData\Local\Temp\ipykernel_1112\2511085918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fake_manual_testing['class'] = 0
# C:\Users\angur\AppData\Local\Temp\ipykernel_1112\2511085918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_true_manual_testing ['class'] = 1

# %%
data_fake_manual_testing.head(10)
# Out:
#                                                    title  \
# 23461  REPORT: ‘Federal Government Escalated the Viol...
# 23462  BOILER ROOM – Oregon Standoff, Cuddle Parties,...
# 23463  Eyewitness Says Feds Ambushed Bundys, 100 Shot...
# 23464  Episode #119 – SUNDAY WIRE: ‘You Know the Dril...
# 23465  ‘There’ll be boots on the ground’: US making n...
# 23466  Boston Brakes? How to Hack a New Car With Your...
# 23467  Oregon Governor Says Feds ‘Must Act’ Against P...
# 23468  Ron Paul on Burns Oregon Standoff and Jury Nul...
# 23469     BOILER ROOM: As the Frogs Slowly Boil – EP #40
# 23470  Arizona Rancher Protesting in Oregon is Target...
#
#                                                     text      subject  \
# 23461   KILLED: Rancher and protest spokesman Robert ...  Middle-east
# 23462  Tune in to the Alternate Current Radio Network...  Middle-east
# 23463  Patrick Henningsen 21st Century Wire UPDATE: 1...  Middle-east
# 23464  Episode #119 of SUNDAY WIRE SHOW finally resum...  Middle-east
# 23465  21st Century Wire says Various parties in Wash...  Middle-east
# 23466  21st Century Wire says For those who still ref...  Middle-east
# 23467  21st Century Wire says So far, after nearly 20...  Middle-east
# 23468  21st Century Wire says If you ve been followin...  Middle-east
# 23469  Tune in to the Alternate Current Radio Network...  Middle-east
# 23470  RTOne of the most visible members of the armed...  Middle-east
#
#                    date  class
# 23461  January 28, 2016      0
# 23462  January 28, 2016      0
# 23463  January 27, 2016      0
# 23464  January 24, 2016      0
# 23465  January 23, 2016      0
# 23466  January 22, 2016      0
# 23467  January 21, 2016      0
# 23468  January 21, 2016      0
# 23469  January 20, 2016      0
# 23470  January 20, 2016      0

# %%
data_true_manual_testing.head(10)
# Out:
#                                                    title  \
# 21297  U.N. panel urges Russia to fight racism by neo...
# 21298  Hostility grows towards Syrian refugees in Leb...
# 21299  China says sanctions won't help as Trump targe...
# 21300  Energy Secretary Perry cancels Kazakhstan visi...
# 21301  Exclusive: India and Pakistan hit by spy malwa...
# 21302  Ireland calls for realism from UK on border is...
# 21303  Former Uzbek leader's daughter to resign as am...
# 21304  U.S. navy recovers remains of all sailors miss...
# 21305  After decades of war, Colombia's FARC rebels d...
# 21306  Father of Philippine Islamist militant leaders...
#
#                                                     text    subject  \
# 21297  GENEVA (Reuters) - A United Nations human righ...  worldnews
# 21298  BEIRUT (Reuters) - Abu Yazan has rarely steppe...  worldnews
# 21299  BEIJING (Reuters) - Venezuela s close ally Chi...  worldnews
# 21300  ALMATY (Reuters) - United States Energy Secret...  worldnews
# 21301  MUMBAI (Reuters) - Symantec Corp, a digital se...  worldnews
# 21302  DUBLIN (Reuters) - Much of the future border a...  worldnews
# 21303  SAMARKAND, Uzbekistan (Reuters) - Lola Karimov...  worldnews
# 21304  SINGAPORE (Reuters) - The U.S. Navy on Monday ...  worldnews
# 21305  BOGOTA (Reuters) - Colombia s leftist FARC reb...  worldnews
# 21306  MANILA (Reuters) - The father of the leaders o...  worldnews
#
#                    date  class
# 21297  August 28, 2017       1
# 21298  August 28, 2017       1
# 21299  August 28, 2017       1
# 21300  August 28, 2017       1
# 21301  August 28, 2017       1
# 21302  August 28, 2017       1
# 21303  August 28, 2017       1
# 21304  August 28, 2017       1
# 21305  August 27, 2017       1
# 21306  August 27, 2017       1

# %%
data_merge = pd.concat([data_fake , data_true] , axis =0)
data_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# 5  The number of cases of cops brutalizing and ki...    News
# 6  Donald Trump spent a good portion of his day a...    News
# 7  In the wake of yet another court decision that...    News
# 8  Many people have raised the alarm regarding th...    News
# 9  Just when you might have thought we d get a br...    News
#
#                 date  class
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0
# 5  December 25, 2017      0
# 6  December 23, 2017      0
# 7  December 23, 2017      0
# 8  December 22, 2017      0
# 9  December 21, 2017      0

# %%
data_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
data = data_merge.drop(['title' , 'subject' ,'date'] , axis =1)

# %%
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
data = data.sample(frac = 1)

# %%
data.head()
# Out:
#                                                     text  class
# 21917  Yeah that whole  taking up arms  thing seems t...      0
# 6204   JERUSALEM (Reuters) - Israel’s right wing has ...      1
# 11436  KHARTOUM (Reuters) - Turkey and Sudan have agr...      1
# 23097   Syrian Army soldier holds up Al Nusra Front (...      0
# 19698  Ohio Governor John Kasich, who signed a pledge...      0

# %%
data.reset_index(inplace = True)
data.drop(['index'] , axis =1,inplace = True)

# %%
data.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
data.head()
# Out:
#                                                 text  class
# 0  Yeah that whole  taking up arms  thing seems t...      0
# 1  JERUSALEM (Reuters) - Israel’s right wing has ...      1
# 2  KHARTOUM (Reuters) - Turkey and Sudan have agr...      1
# 3   Syrian Army soldier holds up Al Nusra Front (...      0
# 4  Ohio Governor John Kasich, who signed a pledge...      0

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]','', text)
    text = re.sub(r"\\W" , "" , text)
    text = re.sub(r'https?://\S+|www\.\S+' , '' , text)
    text = re.sub(r'<,*?>+', '', text)
    text = re.sub(r'[%s]' %re.escape(string.punctuation), '', text)
    text = re.sub(r'\n','',text)
    text= re.sub(r'\w*\d\w*','',text)
    return text

# %%
data['text'] = data['text'].apply(wordopt)

# %%
x = data ['text']
y = data['class']

# %%
x_train, x_test , y_train , y_test =train_test_split(x,y,test_size = 0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(xv_train , y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test , y_test)
# Out:
# 0.9853466761972838

# %%
print(classification_report(y_test , pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5931
#            1       0.98      0.99      0.98      5261
#
#     accuracy                           0.99     11192
#    macro avg       0.99      0.99      0.99     11192
# weighted avg       0.99      0.99      0.99     11192

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(xv_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score(xv_test , y_test)
# Out:
# 0.9960686204431737

# %%
print(classification_report(y_test , pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5931
#            1       0.99      1.00      1.00      5261
#
#     accuracy                           1.00     11192
#    macro avg       1.00      1.00      1.00     11192
# weighted avg       1.00      1.00      1.00     11192

# %%
from sklearn.ensemble import GradientBoostingClassifier
GB = GradientBoostingClassifier(random_state=0)
GB.fit(xv_train , y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gb = GB.predict(xv_test)

# %%
GB.score(xv_test , y_test)
# Out:
# 0.9955325232308792

# %%
print(classification_report(y_test , pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5931
#            1       0.99      1.00      1.00      5261
#
#     accuracy                           1.00     11192
#    macro avg       1.00      1.00      1.00     11192
# weighted avg       1.00      1.00      1.00     11192

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(random_state=0)
RF.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rf = RF.predict(xv_test)

# %%
RF.score(xv_test , y_test)
# Out:
# 0.9850786275911365

# %%
print(classification_report(y_test , pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5931
#            1       0.98      0.98      0.98      5261
#
#     accuracy                           0.99     11192
#    macro avg       0.99      0.99      0.99     11192
# weighted avg       0.99      0.99      0.99     11192

# %%
def output_label(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not a Fake News"

def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)

    # Preprocess text (ensure wordopt() is defined elsewhere)
    new_def_test['text'] = new_def_test["text"].apply(wordopt)

    # Vectorize the text
    new_x_test = vectorization.transform(new_def_test["text"]) 

    # Get predictions from each model
    pred_LR = LR.predict(new_x_test)
    pred_DT = DT.predict(new_x_test)
    pred_GB = GB.predict(new_x_test)
    pred_RF = RF.predict(new_x_test)

    # Return the predictions
    print("\n\nLR Prediction: {} \nDT Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_label(pred_LR[0]),
        output_label(pred_DT[0]),
        output_label(pred_GB[0]),
        output_label(pred_RF[0])
    ))

# %%
news = str(input())
manual_testing(news)
# Out:
# LR Prediction: Not a Fake News
# DT Prediction: Not a Fake News
# GBC Prediction: Not a Fake News
# RFC Prediction: Not a Fake News
